# %%
# %matplotlib notebook
import sys

sys.path.append("../../")
from examples.ortools.cvrp import CVRP

# %% [markdown]
# The data set is created by calling the CVRP class, and the customers are displayed below in blue. The depot is in red.

# %%
data = CVRP()
data.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The CVRP instance is solved as follows :

# %%
data.solve(cspy=True)
# Out:
# vrpy.main - INFO - new upper bound : max num stops = 10
# vrpy.master_solve_pulp - INFO - ['Source', 13, 15, 11, 12, 'Sink'] cost 1552 load 15
# vrpy.master_solve_pulp - INFO - ['Source', 9, 10, 16, 14, 'Sink'] cost 1552 load 15
# vrpy.master_solve_pulp - INFO - ['Source', 5, 6, 2, 8, 'Sink'] cost 1552 load 15
# vrpy.master_solve_pulp - INFO - ['Source', 7, 1, 4, 3, 'Sink'] cost 1552 load 15
# vrpy.master_solve_pulp - INFO - total cost = 6208.0

# %% [markdown]
# The optimal solution has total cost 6208 and 4 vehicles are needed. The routes are displayed below.

# %%
data.plot(solution=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
